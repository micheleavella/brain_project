# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from dask import delayed

# %%
def simulation(N,p,gamma,steps,dt):
    J = p[:N*N].reshape((N,N))     
    np.fill_diagonal(J,0)          
    h = p[N*N:]                    
    
    S = [-np.ones(N)]
    for i in tqdm(range(1,steps)):
        s = np.copy(S[-1])
        H = h + np.dot(J,s)
        p_flip = gamma*dt*0.5*(1-s*np.tanh(H))
        p = np.random.rand(N)
        s[p<p_flip]*=-1
        S.append(s)
    S = np.array(S).T
    return S

def C_and_Cdot(S,dt):
    N = S.shape[0]
    C = np.dot(S, S.T)/S.shape[1]
    C_dot = np.dot(S[:,1:], S[:,:-1].T)/(S.shape[1]-1)
    C_dot -= C
    C_dot /= dt
        
    return C,C_dot      

def grad_L(p,S,C,C_dot,gamma):
    N_t = S.shape[1]
    N = S.shape[0]
    
    # p are the params, S is the spins history
    J = p[:N*N].reshape((N,N))     # NxN matrix
    np.fill_diagonal(J,0)          #removing the diagonal terms for easier sums
    h = p[N*N:]                    # N vector
    
    #grad wrt h
    H = (h + np.dot(J,S).T).T
    G_1 = np.mean(S-np.tanh(H),axis=1)
    
    #grad wrt J
    G_0 = C_dot/gamma + C
    G_0 -= (np.dot(np.tanh(H),S.T))/N_t
    
    #new
    np.fill_diagonal(G_0,0)
    return np.concatenate((G_0.flatten(),G_1))
    
def parralel_grad(p,S_split,C,C_dot,gamma):
    ris = []
    for S in S_split:
        ris.append(delayed(grad_L)(p,S,C,C_dot,gamma))
    grad = delayed(sum)(ris).compute()/len(S_split)
    return grad

# %%
# !ls DATA
# Out:
# params_N10_steps1000000_dt0.1_gamma1.npy
# params_N50_steps100000_dt0.1_gamma1.npy
# spins_N100_steps100000_dt0.1_gamma1.npy
# spins_N100_steps200000_dt0.1_gamma1.npy
# spins_N10_steps1000000_dt0.1_gamma1.npy
# spins_N10_steps100000_dt0.1_gamma1.npy
# spins_N50_steps100000_dt0.1_gamma1.npy

# %%
S = np.load('59_neurons_60k_steps.npy')
S_2=np.concatenate((S,S),axis=1)
#p_real = np.load('DATA/params_N10_steps1000000_dt0.1_gamma1.npy')
#-----------------------params------------------------------------#
gamma = 1
dt = 0.1
N, steps = S_2.shape

C,C_dot = C_and_Cdot(S_2,dt)
#-----------------------n cores------------------------------------#
n_cores = 4

S_split = np.array_split(S_2,n_cores,axis = 1)
#del S

# %%
# %time _ = parralel_grad(p_real,S_split,C,C_dot,gamma)
# %time _ = grad_L(p_real,S_2,C,C_dot,gamma)
# Out:
# CPU times: user 1.28 s, sys: 377 ms, total: 1.66 s
# Wall time: 713 ms
# CPU times: user 941 ms, sys: 259 ms, total: 1.2 s
# Wall time: 912 ms

# %% [markdown]
# ### Optimization

# %% [markdown]
# ### GA with momentum

# %%
np.random.seed(123)
p_mom = np.random.normal(0,2,N*N+N)
v = np.zeros(N*N+N)
### PARAMS
Steps = 300
l_r = 0.1
fric = 0.9
L_mom=[]

for i in tqdm(range(Steps)):
    g = parralel_grad(p_mom,S_split,C,C_dot,gamma)
    v = fric*v + l_r * g
    p_mom += v
    L_mom.append(L(p_mom,S_split,C,C_dot,gamma))
    
plt.plot(L_mom)
      
plt.figure(figsize=(7,5))
plt.plot(p_mom,p_real,'o')
plt.plot([min(p_real),max(p_real)],[min(p_real),max(p_real)],'--',color ='red')
plt.title('GA with mom (MSE: '+str(np.sum((p_mom-p_real)**2))[:4]+')')
# Out:
#   7%|▋         | 20/300 [00:13<03:02,  1.54it/s]
# -------------------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-7-bba28751450f> in <module>
#       8
#       9 for i in tqdm(range(Steps)):
# ---> 10     g = parralel_grad(p_mom,S_split,C,C_dot,gamma)
#      11     v = fric*v + l_r * g
#      12     p_mom += v
#
# <ipython-input-2-49383f13793a> in parralel_grad(p, S_split, C, C_dot, gamma)
#      49     for S in S_split:
#      50         ris.append(delayed(grad_L)(p,S,C,C_dot,gamma))
# ---> 51     grad = delayed(sum)(ris).compute()/len(S_split)
#      52     return grad
#
# ~/anaconda3/envs/mag/lib/python3.8/site-packages/dask/base.py in compute(self, **kwargs)
#     282         dask.base.compute
#     283         """
# --> 284         (result,) = compute(self, traverse=False, **kwargs)
#     285         return result
#     286
#
# ~/anaconda3/envs/mag/lib/python3.8/site-packages/dask/base.py in compute(*args, **kwargs)
#     564         postcomputes.append(x.__dask_postcompute__())
#     565
# --> 566     results = schedule(dsk, keys, **kwargs)
#     567     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     568
#
# ~/anaconda3/envs/mag/lib/python3.8/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      77             pool = MultiprocessingPoolExecutor(pool)
#      78
# ---> 79     results = get_async(
#      80         pool.submit,
#      81         pool._max_workers,
#
# ~/anaconda3/envs/mag/lib/python3.8/site-packages/dask/local.py in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     501             while state["waiting"] or state["ready"] or state["running"]:
#     502                 fire_tasks(chunksize)
# --> 503                 for key, res_info, failed in queue_get(queue).result():
#     504                     if failed:
#     505                         exc, tb = loads(res_info)
#
# ~/anaconda3/envs/mag/lib/python3.8/site-packages/dask/local.py in queue_get(q)
#     132
#     133     def queue_get(q):
# --> 134         return q.get()
#     135
#     136
#
# ~/anaconda3/envs/mag/lib/python3.8/queue.py in get(self, block, timeout)
#     168             elif timeout is None:
#     169                 while not self._qsize():
# --> 170                     self.not_empty.wait()
#     171             elif timeout < 0:
#     172                 raise ValueError("'timeout' must be a non-negative number")
#
# ~/anaconda3/envs/mag/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### RMS PROP

# %%
np.random.seed(1234)
p_rms = np.random.normal(0,2,N*N+N)
s = np.zeros(N*N+N)
### PARAMS
Steps = 300
l_r = 0.05
beta = 0.9
eps = 10**(-8)


for i in tqdm(range(Steps)):
    g = parralel_grad(p_rms,S_split,C,C_dot,gamma)
    s = beta * s + (1-beta)*g*g
    p_rms += l_r*g/np.sqrt(s+eps)                                      
    

print('MSE: ',np.sum((p_rms-p_real)**2))      
#plt.plot(ris)
plt.figure(figsize=(7,5))
plt.plot(p_rms,p_real,'o')
plt.plot([min(p_real),max(p_real)],[min(p_real),max(p_real)],'--',color ='red')
plt.title('RMS (MSE: '+str(np.sum((p_rms-p_real)**2))[:4]+')')
# Out:
# 100%|██████████| 300/300 [02:05<00:00,  2.39it/s]
# MSE:  0.48453776728761455
# Text(0.5, 1.0, 'RMS (MSE: 0.48)')

# %% [markdown]
# ### Comparison between medium magnetization per site

# %%
np.random.seed(123)
J = np.random.normal(0,1,(N,N))
np.fill_diagonal(J,0)
h = np.random.normal(0,1,N)
p_rand = np.concatenate((J.flatten(),h))

# %%
steps = 100_000

S_rms = simulation(N,p_rms,gamma,steps,dt)
S_mom = simulation(N,p_mom,gamma,steps,dt)
S_rand = simulation(N,p_rand,gamma,steps,dt)
S_real = simulation(N,p_real,gamma,steps,dt)


M = np.mean(S, axis = 1)
M_mom = np.mean(S_mom, axis = 1)
M_rms = np.mean(S_rms, axis = 1)
M_rand = np.mean(S_rand, axis = 1)
M_real = np.mean(S_real, axis = 1)

sigma = np.std(S, axis = 1)/np.sqrt(steps)
# Out:
# 100%|██████████| 99999/99999 [00:01<00:00, 58574.06it/s]
# 100%|██████████| 99999/99999 [00:01<00:00, 61172.24it/s]
# 100%|██████████| 99999/99999 [00:01<00:00, 61922.87it/s]
# 100%|██████████| 99999/99999 [00:01<00:00, 62623.03it/s]

# %%
fig, axs = plt.subplots(2, 2 ,figsize=(12,10))
axs[0, 0].plot(M_rms,M,'o')
axs[0, 0].set_title('RMS (MSE: '+str(np.sum((M_rms-M)**2))[:5]+')')
axs[0, 1].plot(M_mom,M,'o')
axs[0, 1].set_title('SGA mom (MSE: '+str(np.sum((M_mom-M)**2))[:5]+')')
axs[1, 0].plot(M_rand,M,'o')
axs[1, 0].set_title('Random (MSE: '+str(np.sum((M_rand-M)**2))[:5]+')')
axs[1, 1].plot(M_real,M,'o')
axs[1, 1].set_title('Real (MSE: '+str(np.sum((M_real-M)**2))[:5]+')')


for ax in axs.flat:
    ax.plot([min(M),max(M)],[min(M),max(M)],'--',color ='red')

# %% [markdown]
# ### Comparison between correlation matrix

# %%
C_o = C_and_Cdot(S,dt)[0].flatten()
C_mom = C_and_Cdot(S_mom,dt)[0].flatten()
C_rms = C_and_Cdot(S_rms,dt)[0].flatten()
C_rand = C_and_Cdot(S_rand,dt)[0].flatten()
C_real = C_and_Cdot(S_real,dt)[0].flatten()

# %%
fig, axs = plt.subplots(2, 2 ,figsize=(12,10))
axs[0, 0].plot(C_rms,C_o,'o')
axs[0, 0].set_title('RMS (MSE: '+str(np.sum((C_rms-C_o)**2))[:5]+')')
axs[0, 1].plot(C_mom,C_o,'o')
axs[0, 1].set_title('SGA mom (MSE: '+str(np.sum((C_mom-C_o)**2))[:5]+')')
axs[1, 0].plot(C_rand,C_o,'o')
axs[1, 0].set_title('Random (MSE: '+str(np.sum((C_rand-C_o)**2))[:5]+')')
axs[1, 1].plot(C_real,C_o,'o')
axs[1, 1].set_title('Real (MSE: '+str(np.sum((C_real-C_o)**2))[:5]+')')


for ax in axs.flat:
    ax.plot([min(C_o),max(C_o)],[min(C_o),max(C_o)],'--',color ='red')
